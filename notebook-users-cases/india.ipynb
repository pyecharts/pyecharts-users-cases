# %%
from pyecharts import Map

value = [1, 100]
attr = ['Gujarat', 'Tamil Nadu']
map = Map('India', width=800, height=600)
map.add('', attr, value, maptype=u'印度', is_visualmap=True, visual_text_color="#000")
map
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'India': '/nbextensions/echarts-countries-js/India'
#          }
#     });
# </script>
# <div id="34866ca7b8f146189119aa20c6703f9a" style="width:800px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'India' ],function(ec){
# 	var myChart = ec.init(document.getElementById('34866ca7b8f146189119aa20c6703f9a'));
# var option =  {
#     "title": [
#         {
#             "text": "India",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "top": "auto",
#             "subtext": "",
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "left": "auto"
#         }
#     ],
#     "backgroundColor": "#fff",
#     "series": [
#         {
#             "roam": true,
#             "mapType": "\u5370\u5ea6",
#             "type": "map",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "show": false,
#                     "formatter": null,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "show": true,
#                     "position": null
#                 }
#             },
#             "data": [
#                 {
#                     "value": 1,
#                     "name": "Gujarat"
#                 },
#                 {
#                     "value": 100,
#                     "name": "Tamil Nadu"
#                 }
#             ],
#             "symbol": "circle",
#             "name": "",
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "top": "top",
#             "data": [
#                 ""
#             ],
#             "left": "center",
#             "orient": "horizontal"
#         }
#     ],
#     "series_id": 1354310,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "dimension": null,
#         "min": 0,
#         "type": "continuous",
#         "orient": "vertical",
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "top": "bottom",
#         "textStyle": {
#             "color": "#000"
#         },
#         "showLabel": true,
#         "splitNumber": 5,
#         "left": "left",
#         "text": [
#             "high",
#             "low"
#         ],
#         "calculable": true,
#         "max": 100
#     },
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "trigger": "item",
#         "formatter": null,
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         }
#     }
# };
# myChart.setOption(option);
#
#     });
# </script>
